# %%
import torch
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path
import cv2
from PIL import Image
import random

import torch
from IPython.display import display, Image
from PIL import Image
import cv2
import numpy as np

# %%
model_custom = torch.hub.load("ultralytics/yolov5", "custom", path="C:/Users/Alex/Desktop/HackUPC/hackupc-2024/last.pt")
# Out:
# Using cache found in C:\Users\Alex/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-11-12 Python-3.12.2 torch-2.2.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
model_custom.eval()
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
'''
def detect_webcam(model):
    cap = cv2.VideoCapture(0)  # Webcam capture
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        results = model(frame)  # Perform inference
        frame = results.imgs[0]
        cv2.imshow('YOLOv5', frame)
        if cv2.waitKey(1) == ord('q'):  # Quit on 'q' key press
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
#   Cell In[29], line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %%
def detect_webcam(model):
    cap = cv2.VideoCapture(0)  # Webcam capture
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        results = model(frame) 
        print(results) # Perform inference
        for pred in results.pred:
            for *box, conf, cls in pred:
                x1, y1, x2, y2 = [int(i) for i in box]
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, f'{model.names[int(cls)]}: {conf:.2f}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        cv2.imshow('YOLOv5', frame)
        if cv2.waitKey(1) == ord('q'):  # Quit on 'q' key press
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
detect_webcam(model_custom)
# Out:
# image 1/1: 480x640 1 Up
# Speed: 15.0ms pre-process, 280.2ms inference, 2.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 3.0ms pre-process, 283.6ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 2.0ms pre-process, 268.6ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 2.0ms pre-process, 255.1ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 2.0ms pre-process, 241.1ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 2.0ms pre-process, 251.4ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# Speed: 3.0ms pre-process, 258.6ms inference, 1.0ms NMS per image at shape (1, 3, 480, 640)
# image 1/1: 480x640 (no detections)
# ...
